# %% [markdown]
# # Experiment 1 - Results

# %%
# !pip install plotly > 5.2 -U
# !pip list | grep -i plotly
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# plotly                        5.4.0

# %%
# Mount to Google Drive to save results
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/MSc/2020-21/Research\ Project/Colab/
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/MSc/2020-21/Research Project/Colab
#  5.2                                       risdal_1250.parquet.yml
#  bharadwaj.csv                             risdal_2500.parquet
#  domain_count_df.csv                       risdal_2500.parquet.yml
#  experiment_1_res_times_only.csv           risdal_5000.parquet
#  experiment_1_res_times_stage_1_only.csv   risdal_5000.parquet.yml
#  experiment_1_res_times_stage_2_only.csv   risdal_7500.parquet
# 'fake_news_eda.ipynb - Colaboratory.pdf'   risdal_7500.parquet.yml
#  label_count_df.csv                        risdal.csv
#  reuse_content_df.csv                      risdal.parquet
#  reuse_content_domain_df.csv               risdal.parquet.yml
#  reuse_content_url_df.csv                  stage_1_combi_res_df.csv
#  risdal_10000.parquet                      stage_2_combi_res_df.csv
#  risdal_10000.parquet_10000.yml            template.yml
#  risdal_1250.parquet

# %%
# Connect to GCP Bucket
from google.colab import auth
auth.authenticate_user()

# %%
# Set GCP project ID and region to Europe West 2 - London
PROJECT = 'fake-news-bs-detector'
# !gcloud config set project $PROJECT
REGION = 'europe-west2'
CLUSTER = '{}-cluster'.format(PROJECT)
# !gcloud config set compute/region $REGION
# !gcloud config list # show some information
# Out:
# Updated property [core/project].
# Updated property [compute/region].
# [component_manager]
# disable_update_check = True
# [compute]
# gce_metadata_read_timeout_sec = 0
# region = europe-west2
# [core]
# account = aaron.altrock@gmail.com
# project = fake-news-bs-detector
#
# Your active configuration is: [default]

# %% [markdown]
# ## Read in the results in CSV files

# %%
# Read in from the Google Drive at mount point
stage_1_res_file_nm = 'experiment_1_res_times_stage_1_only.csv'
stage_1_res_df = pd.read_csv(stage_1_res_file_nm)
print('Stage 1: Dimension of {}: {} x {}'.format(stage_1_res_file_nm, stage_1_res_df.shape[0], stage_1_res_df.shape[1]))

stage_2_res_file_nm = 'experiment_1_res_times_stage_2_only.csv'
stage_2_res_df = pd.read_csv(stage_2_res_file_nm)
print('Stage 2: Dimension of {}: {} x {}'.format(stage_2_res_file_nm, stage_2_res_df.shape[0], stage_2_res_df.shape[1]))
# Out:
# Stage 1: Dimension of experiment_1_res_times_stage_1_only.csv: 25 x 6
# Stage 2: Dimension of experiment_1_res_times_stage_2_only.csv: 25 x 6

# %%
# Stage 1 
stage_1_res_df
# Out:
#      Size    Stage      1a      1b   1c   1d
# 0    1250  Stage 1   45.64  108.75  324  475
# 1    1250  Stage 1   34.59  111.45  352  456
# 2    1250  Stage 1   35.49  107.28  356  458
# 3    1250  Stage 1   40.17  114.64  352  460
# 4    1250  Stage 1   36.37  109.30  357  491
# 5    2500  Stage 1   54.78  179.32  410  461
# 6    2500  Stage 1   54.74  180.87  366  460
# 7    2500  Stage 1   56.80  177.27  324  476
# 8    2500  Stage 1   55.48  184.47  370  441
# 9    2500  Stage 1   56.78  184.47  338  469
# 10   5000  Stage 1   93.97  316.24  387  481
# 11   5000  Stage 1   93.74  316.33  390  470
# 12   5000  Stage 1   86.70  318.98  388  476
# 13   5000  Stage 1   86.11  318.89  386  490
# 14   5000  Stage 1   96.43  315.89  383  463
# 15   7500  Stage 1  123.78  460.87  437  490
# 16   7500  Stage 1  115.69  461.42  394  479
# 17   7500  Stage 1  118.07  453.42  435  486
# 18   7500  Stage 1  107.34  445.36  404  481
# 19   7500  Stage 1  120.60  456.97  425  517
# 20  10000  Stage 1  138.07  589.86  432  528
# 21  10000  Stage 1  148.76  597.21  417  519
# 22  10000  Stage 1  145.63  583.60  412  519
# 23  10000  Stage 1  157.13  587.03  463  515
# 24  10000  Stage 1  136.55  578.63  424  537

# %%
# Stage 2
stage_2_res_df
# Out:
#      Size    Stage       1a       1b   1c     1d
# 0    1250  Stage 2   819.29  1015.82  545    991
# 1    1250  Stage 2   824.67  1148.38  550   1051
# 2    1250  Stage 2   828.73   911.12  500    990
# 3    1250  Stage 2   817.50   883.08  511   1053
# 4    1250  Stage 2   863.63   893.00  541    996
# 5    2500  Stage 2  1081.60  1710.55  666   1545
# 6    2500  Stage 2  1102.60  1698.07  672   1347
# 7    2500  Stage 2  1117.81  1733.36  645   1312
# 8    2500  Stage 2  1145.76  1692.81  630   2217
# 9    2500  Stage 2  1144.45  1723.29  656   1475
# 10   5000  Stage 2  2266.50  3376.45  722  11040
# 11   5000  Stage 2  2401.96  3314.00  719  10920
# 12   5000  Stage 2  2275.75  3300.71  716   1929
# 13   5000  Stage 2  2361.90  3384.26  714  11120
# 14   5000  Stage 2  2407.71  3406.24  744  10911
# 15   7500  Stage 2  3389.87  4951.13  825  16316
# 16   7500  Stage 2  3340.29  5181.59  756  16036
# 17   7500  Stage 2  3309.41  5013.33  826  16472
# 18   7500  Stage 2  3525.25  4937.27  797  16101
# 19   7500  Stage 2  3603.67  5058.46  824  16102
# 20  10000  Stage 2  4477.78  7104.61  819  21090
# 21  10000  Stage 2  4594.12  7096.48  823  21944
# 22  10000  Stage 2  4652.96  7238.87  822  21949
# 23  10000  Stage 2  4614.27  7142.76  807  21296
# 24  10000  Stage 2  4721.13  6945.32  821  21621

# %%
# Melt the two data frames into tidy forms for Stage 1 and 2 results
stage_1_res_melted_df = pd.melt(stage_1_res_df, id_vars=['Size', 'Stage'])
stage_2_res_melted_df = pd.melt(stage_2_res_df, id_vars=['Size', 'Stage'])

# Calculate Median points
stage_1_res_q50_df = stage_1_res_melted_df.groupby(['Size', 'Stage', 'variable']).quantile(q=.5).reset_index().sort_values(by=['Stage', 'Size', 'variable'])
stage_2_res_q50_df = stage_2_res_melted_df.groupby(['Size', 'Stage', 'variable']).quantile(q=.5).reset_index().sort_values(by=['Stage', 'Size', 'variable'])

# %%
stage_1_res_q50_df
# Out:
#      Size    Stage variable   value
# 0    1250  Stage 1       1a   36.37
# 1    1250  Stage 1       1b  109.30
# 2    1250  Stage 1       1c  352.00
# 3    1250  Stage 1       1d  460.00
# 4    2500  Stage 1       1a   55.48
# 5    2500  Stage 1       1b  180.87
# 6    2500  Stage 1       1c  366.00
# 7    2500  Stage 1       1d  461.00
# 8    5000  Stage 1       1a   93.74
# 9    5000  Stage 1       1b  316.33
# 10   5000  Stage 1       1c  387.00
# 11   5000  Stage 1       1d  476.00
# 12   7500  Stage 1       1a  118.07
# 13   7500  Stage 1       1b  456.97
# 14   7500  Stage 1       1c  425.00
# 15   7500  Stage 1       1d  486.00
# 16  10000  Stage 1       1a  145.63
# 17  10000  Stage 1       1b  587.03
# 18  10000  Stage 1       1c  424.00
# 19  10000  Stage 1       1d  519.00

# %%
stage_2_res_q50_df
# Out:
#      Size    Stage variable     value
# 0    1250  Stage 2       1a    824.67
# 1    1250  Stage 2       1b    911.12
# 2    1250  Stage 2       1c    541.00
# 3    1250  Stage 2       1d    996.00
# 4    2500  Stage 2       1a   1117.81
# 5    2500  Stage 2       1b   1710.55
# 6    2500  Stage 2       1c    656.00
# 7    2500  Stage 2       1d   1475.00
# 8    5000  Stage 2       1a   2361.90
# 9    5000  Stage 2       1b   3376.45
# 10   5000  Stage 2       1c    719.00
# 11   5000  Stage 2       1d  10920.00
# 12   7500  Stage 2       1a   3389.87
# 13   7500  Stage 2       1b   5013.33
# 14   7500  Stage 2       1c    824.00
# 15   7500  Stage 2       1d  16102.00
# 16  10000  Stage 2       1a   4614.27
# 17  10000  Stage 2       1b   7104.61
# 18  10000  Stage 2       1c    821.00
# 19  10000  Stage 2       1d  21621.00

# %%
# Fit regression by Ordinary Least Squares (OLS)
# Ref https://plotly.com/python/linear-fits/
fig = px.scatter(stage_1_res_melted_df, x='Size', y='value', color='variable', trendline='ols', trendline_options=dict(log_x=False),
                 title='Stage 1 pipeline time taken to process varying batch size', width=800, height=800,
                 labels={
                     'Size': 'batch size (no. of publications)',
                     'value': 'time taken (sec)',
                     'variable': 'configuration'}
                 )
res = px.get_trendline_results(fig)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="20f55293-dcde-464d-b8fe-9653cf508951" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20f55293-dcde-464d-b8fe-9653cf508951")) {                    Plotly.newPlot(                        "20f55293-dcde-464d-b8fe-9653cf508951",                        [{"hovertemplate":"configuration=1a<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1a","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"1a","orientation":"v","showlegend":true,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[45.64,34.59,35.49,40.17,36.37,54.78,54.74,56.8,55.48,56.78,93.97,93.74,86.7,86.11,96.43,123.78,115.69,118.07,107.34,120.6,138.07,148.76,145.63,157.13,136.55],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>value = 0.0121644 * Size + 25.7134<br>R<sup>2</sup>=0.979791<br><br>configuration=1a<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y} <b>(trend)</b><extra></extra>","legendgroup":"1a","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"1a","showlegend":false,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[40.91887804878049,40.91887804878049,40.91887804878049,40.91887804878049,40.91887804878049,56.12435365853659,56.12435365853659,56.12435365853659,56.12435365853659,56.12435365853659,86.53530487804879,86.53530487804879,86.53530487804879,86.53530487804879,86.53530487804879,116.94625609756099,116.94625609756099,116.94625609756099,116.94625609756099,116.94625609756099,147.3572073170732,147.3572073170732,147.3572073170732,147.3572073170732,147.3572073170732],"yaxis":"y","type":"scatter"},{"hovertemplate":"configuration=1b<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1b","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"1b","orientation":"v","showlegend":true,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[108.75,111.45,107.28,114.64,109.3,179.32,180.87,177.27,184.47,184.47,316.24,316.33,318.98,318.89,315.89,460.87,461.42,453.42,445.36,456.97,589.86,597.21,583.6,587.03,578.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>value = 0.0545494 * Size + 43.9562<br>R<sup>2</sup>=0.999307<br><br>configuration=1b<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y} <b>(trend)</b><extra></extra>","legendgroup":"1b","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"1b","showlegend":false,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[112.1430243902439,112.1430243902439,112.1430243902439,112.1430243902439,112.1430243902439,180.32982926829268,180.32982926829268,180.32982926829268,180.32982926829268,180.32982926829268,316.70343902439026,316.70343902439026,316.70343902439026,316.70343902439026,316.70343902439026,453.0770487804878,453.0770487804878,453.0770487804878,453.0770487804878,453.0770487804878,589.4506585365855,589.4506585365855,589.4506585365855,589.4506585365855,589.4506585365855],"yaxis":"y","type":"scatter"},{"hovertemplate":"configuration=1c<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1c","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"1c","orientation":"v","showlegend":true,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500, ...

# %%
# Print the regression details
print('Regression results - 1a:')
print(res.query('configuration == \'1a\'').px_fit_results.iloc[0].summary())
print('Regression results - 1b:')
print(res.query('configuration == \'1b\'').px_fit_results.iloc[0].summary())
print('Regression results - 1c:')
print(res.query('configuration == \'1c\'').px_fit_results.iloc[0].summary())
print('Regression results - 1d:')
print(res.query('configuration == \'1d\'').px_fit_results.iloc[0].summary())
# Out:
# Regression results - 1a:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     1115.
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           5.42e-21
# Time:                        23:52:43   Log-Likelihood:                -78.512
# No. Observations:                  25   AIC:                             161.0
# Df Residuals:                      23   BIC:                             163.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.7134      2.240     11.479      0.000      21.080      30.347
# x1             0.0122      0.000     33.394      0.000       0.011       0.013
# ==============================================================================
# Omnibus:                        0.125   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.940   Jarque-Bera (JB):                0.340
# Skew:                          -0.070   Prob(JB):                        0.844
# Kurtosis:                       2.446   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1b:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.318e+04
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           7.64e-38
# Time:                        23:52:43   Log-Likelihood:                -73.616
# No. Observations:                  25   AIC:                             151.2
# Df Residuals:                      23   BIC:                             153.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         43.9562      1.842     23.869      0.000      40.147      47.766
# x1             0.0545      0.000    182.146      0.000       0.054       0.055
# ==============================================================================
# Omnibus:                        0.324   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.850   Jarque-Bera (JB):                0.118
# Skew:                          -0.160   Prob(JB):                        0.943
# Kurtosis:                       2.896   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1c:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     63.78
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           4.42e-08
# Time:                        23:52:43   Log-Likelihood:                -108.74
# No. Observations:                  25   AIC:                             221.5
# Df Residuals:                      23   BIC:                             223.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        337.8768      7.504     45.028      0.000     322.354     353.400
# x1             0.0097      0.001      7.986      0.000       0.007       0.012
# ==============================================================================
# Omnibus:                        1.352   Durbin-Watson:                   2.286
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                0.495
# Skew:                           0.317   Prob(JB):                        0.781
# Kurtosis:                       3.273   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1d:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.691
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     51.48
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           2.63e-07
# Time:                        23:52:43   Log-Likelihood:                -101.14
# No. Observations:                  25   AIC:                             206.3
# Df Residuals:                      23   BIC:                             208.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        450.0024      5.537     81.273      0.000     438.548     461.456
# x1             0.0065      0.001      7.175      0.000       0.005       0.008
# ==============================================================================
# Omnibus:                        0.643   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.725   Jarque-Bera (JB):                0.504
# Skew:                           0.323   Prob(JB):                        0.777
# Kurtosis:                       2.741   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Fit regression by Ordinary Least Squares (OLS)
fig = px.scatter(stage_2_res_melted_df, x='Size', y='value', color='variable', trendline='ols', 
                 title='Stage 2 pipeline time taken to process varying batch size', width=800, height=800,
                 labels={
                     'Size': 'batch size (no. of publications)',
                     'value': 'time taken (sec)',
                     'variable': 'configuration'
                 })
res = px.get_trendline_results(fig)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="320b8541-63eb-4e37-b48f-62389aff7aa3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("320b8541-63eb-4e37-b48f-62389aff7aa3")) {                    Plotly.newPlot(                        "320b8541-63eb-4e37-b48f-62389aff7aa3",                        [{"hovertemplate":"configuration=1a<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1a","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"1a","orientation":"v","showlegend":true,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[819.29,824.67,828.73,817.5,863.63,1081.6,1102.6,1117.81,1145.76,1144.45,2266.5,2401.96,2275.75,2361.9,2407.71,3389.87,3340.29,3309.41,3525.25,3603.67,4477.78,4594.12,4652.96,4614.27,4721.13],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>value = 0.441924 * Size + 147.444<br>R<sup>2</sup>=0.993870<br><br>configuration=1a<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y} <b>(trend)</b><extra></extra>","legendgroup":"1a","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"1a","showlegend":false,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[699.8488292682927,699.8488292682927,699.8488292682927,699.8488292682927,699.8488292682927,1252.2536951219513,1252.2536951219513,1252.2536951219513,1252.2536951219513,1252.2536951219513,2357.063426829269,2357.063426829269,2357.063426829269,2357.063426829269,2357.063426829269,3461.873158536586,3461.873158536586,3461.873158536586,3461.873158536586,3461.873158536586,4566.682890243903,4566.682890243903,4566.682890243903,4566.682890243903,4566.682890243903],"yaxis":"y","type":"scatter"},{"hovertemplate":"configuration=1b<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1b","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"1b","orientation":"v","showlegend":true,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[1015.82,1148.38,911.12,883.08,893.0,1710.55,1698.07,1733.36,1692.81,1723.29,3376.45,3314.0,3300.71,3384.26,3406.24,4951.13,5181.59,5013.33,4937.27,5058.46,7104.61,7096.48,7238.87,7142.76,6945.32],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>value = 0.695381 * Size + -16.3135<br>R<sup>2</sup>=0.995540<br><br>configuration=1b<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y} <b>(trend)</b><extra></extra>","legendgroup":"1b","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"1b","showlegend":false,"x":[1250,1250,1250,1250,1250,2500,2500,2500,2500,2500,5000,5000,5000,5000,5000,7500,7500,7500,7500,7500,10000,10000,10000,10000,10000],"xaxis":"x","y":[852.9131707317074,852.9131707317074,852.9131707317074,852.9131707317074,852.9131707317074,1722.139804878049,1722.139804878049,1722.139804878049,1722.139804878049,1722.139804878049,3460.593073170732,3460.593073170732,3460.593073170732,3460.593073170732,3460.593073170732,5199.046341463415,5199.046341463415,5199.046341463415,5199.046341463415,5199.046341463415,6937.499609756098,6937.499609756098,6937.499609756098,6937.499609756098,6937.499609756098],"yaxis":"y","type":"scatter"},{"hovertemplate":"configuration=1c<br>batch size (no. of publications)=%{x}<br>time taken (sec)=%{y}<extra></extra>","legendgroup":"1c","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"1c","orientation":"v","showlegend":true,"x":[1250,1 ...

# %%
# Print the regression details
print('Regression results - 1a:')
print(res.query('configuration == \'1a\'').px_fit_results.iloc[0].summary())
print('Regression results - 1b:')
print(res.query('configuration == \'1b\'').px_fit_results.iloc[0].summary())
print('Regression results - 1c:')
print(res.query('configuration == \'1c\'').px_fit_results.iloc[0].summary())
print('Regression results - 1d:')
print(res.query('configuration == \'1d\'').px_fit_results.iloc[0].summary())
# Out:
# Regression results - 1a:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     3729.
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           5.93e-27
# Time:                        23:52:56   Log-Likelihood:                -153.24
# No. Observations:                  25   AIC:                             310.5
# Df Residuals:                      23   BIC:                             312.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        147.4440     44.500      3.313      0.003      55.390     239.498
# x1             0.4419      0.007     61.067      0.000       0.427       0.457
# ==============================================================================
# Omnibus:                       13.199   Durbin-Watson:                   1.050
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                2.451
# Skew:                          -0.038   Prob(JB):                        0.294
# Kurtosis:                       1.468   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1b:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     5134.
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           1.53e-28
# Time:                        23:52:56   Log-Likelihood:                -160.57
# No. Observations:                  25   AIC:                             325.1
# Df Residuals:                      23   BIC:                             327.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -16.3135     59.678     -0.273      0.787    -139.768     107.141
# x1             0.6954      0.010     71.651      0.000       0.675       0.715
# ==============================================================================
# Omnibus:                        0.533   Durbin-Watson:                   0.699
# Prob(Omnibus):                  0.766   Jarque-Bera (JB):                0.600
# Skew:                           0.293   Prob(JB):                        0.741
# Kurtosis:                       2.519   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1c:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     142.8
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           2.41e-11
# Time:                        23:52:56   Log-Likelihood:                -127.83
# No. Observations:                  25   AIC:                             259.7
# Df Residuals:                      23   BIC:                             262.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        541.7585     16.104     33.641      0.000     508.445     575.072
# x1             0.0313      0.003     11.949      0.000       0.026       0.037
# ==============================================================================
# Omnibus:                        4.518   Durbin-Watson:                   0.812
# Prob(Omnibus):                  0.104   Jarque-Bera (JB):                1.875
# Skew:                          -0.304   Prob(JB):                        0.392
# Kurtosis:                       1.804   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results - 1d:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     427.7
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):           2.33e-16
# Time:                        23:52:56   Log-Likelihood:                -223.66
# No. Observations:                  25   AIC:                             451.3
# Df Residuals:                      23   BIC:                             453.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3226.2329    744.173     -4.335      0.000   -4765.672   -1686.794
# x1             2.5027      0.121     20.680      0.000       2.252       2.753
# ==============================================================================
# Omnibus:                       31.988   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.510
# Skew:                          -2.416   Prob(JB):                     2.43e-17
# Kurtosis:                      10.078   Cond. No.                     1.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
