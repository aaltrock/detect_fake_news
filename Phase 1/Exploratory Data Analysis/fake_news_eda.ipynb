# %% [markdown]
# # Data validation between the data set in BigQuery and GraphDB
#
# The objectives are to:
# 1. Ensure complete upload of data to BigQuery and GraphDB.
# 2. Check for data qualtiy issues.
# 3. Gain insights on the data.
# 4. Engineer features.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Mount to Google Drive to save results
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/MSc/2020-21/Research\ Project/Colab/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/MSc/2020-21/Research Project/Colab
# label_count_df.csv

# %%
# Connect to GCP Bucket
from google.colab import auth
auth.authenticate_user()

# %%
# Set GCP project ID and region to Europe West 2 - London
PROJECT = 'detect-fake-news-313201'
# !gcloud config set project $PROJECT
REGION = 'europe-west2'
CLUSTER = '{}-cluster'.format(PROJECT)
# !gcloud config set compute/region $REGION
# !gcloud config set dataproc/region $REGION

# !gcloud config list # show some information
# Out:
# Updated property [core/project].
# Updated property [compute/region].
# Updated property [dataproc/region].
# [component_manager]
# disable_update_check = True
# [compute]
# gce_metadata_read_timeout_sec = 0
# region = europe-west2
# [core]
# account = aaron.altrock@gmail.com
# project = detect-fake-news-313201
# [dataproc]
# region = europe-west2
#
# Your active configuration is: [default]

# %% [markdown]
# ## Check the number of files in successive GCP cloud storage buckets

# %%
# Count the number of cleaned JSON files from the end of stage 1 in the pipeline
# !gsutil ls -l gs://fake_news_cleaned_json/*.json | wc -l
# Out:
# 59733

# %%
# Count the number of parsed JSON and TTL files into triples at the end of stage 2 in the pipeline
# !gsutil ls -l gs://fake_news_ttl_json/*.ttl | wc -l
# !gsutil ls -l gs://fake_news_ttl_json/*.json | wc -l
# Out:
# 27590
# 27590

# %% [markdown]
# The variance between the 59,733 cleaned files to 27,590 turtle documents would suggest this is due to the raw data containing duplicating records for the same news web page, when the turtles are indexed by the hash value of the URLs and therefore would overwrite leading to small number of samples.

# %%
# Based on https://cloud.google.com/bigquery/docs/quickstarts/quickstart-client-libraries#bigquery_simple_app_client-python
from google.cloud import bigquery
client = bigquery.Client(PROJECT)

# %% [markdown]
# ## Profile the data in its original form held in BigQuery

# %%
# BIgQuery data row count
query_job = client.query(
    """
    SELECT COUNT(*) AS POPULATION_COUNT
    FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
    """
)

res_df = query_job.result().to_dataframe()  # Waits for job to complete.

res_df
# Out:
#    POPULATION_COUNT
# 0             27589

# %% [markdown]
# Therefore deviation by one record compared to the number of files in `gs://fake_news_ttl_json`.

# %%
# BIgQuery data row count
query_job = client.query(
    """
    WITH URL_LIST AS (
      SELECT 
      URL
      , COUNT(*) AS URL_COUNT
      FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
      GROUP BY URL
    )
    SELECT * FROM URL_LIST WHERE URL_COUNT > 1
    """
)

res_df = query_job.result().to_dataframe()  # Waits for job to complete.

res_df
# Out:
# Empty DataFrame
# Columns: [URL, URL_COUNT]
# Index: []

# %% [markdown]
# Therefore no samples found to have duplicating URL in the BigQuery table, and all articles have unique URLs.

# %%
# BIgQuery data preview
query_job = client.query(
    """
    SELECT *
    FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
    LIMIT 10
    """
)

res_df = query_job.result().to_dataframe()  # Waits for job to complete.

res_df
# Out:
#                                                  url   domain  \
# 0  http://awm.com/woman-adopts-rescue-dog-starts-...  awm.com
# 1  http://awm.com/grand-daughter-sings-favorite-s...  awm.com
# 2  http://awm.com/first-class-passenger-sees-a-so...  awm.com
# 3  http://awm.com/model-who-boasts-she-transforme...  awm.com
# 4  http://awm.com/dad-puts-his-son-into-the-game-...  awm.com
# 5  http://awm.com/little-girls-reaction-to-shooti...  awm.com
# 6  http://awm.com/out-of-all-the-holiday-recipes-...  awm.com
# 7  http://awm.com/a-starbucks-barista-couldnt-fin...  awm.com
# 8  http://awm.com/the-easily-offended-whine-when-...  awm.com
# 9  http://awm.com/during-heated-love-making-wife-...  awm.com
#
#                                domain_hash  \
# 0  domain_9725d0802cf38288710d8bff8f64dcba
# 1  domain_9725d0802cf38288710d8bff8f64dcba
# 2  domain_9725d0802cf38288710d8bff8f64dcba
# 3  domain_9725d0802cf38288710d8bff8f64dcba
# 4  domain_9725d0802cf38288710d8bff8f64dcba
# 5  domain_9725d0802cf38288710d8bff8f64dcba
# 6  domain_9725d0802cf38288710d8bff8f64dcba
# 7  domain_9725d0802cf38288710d8bff8f64dcba
# 8  domain_9725d0802cf38288710d8bff8f64dcba
# 9  domain_9725d0802cf38288710d8bff8f64dcba
#
#                                title_hash  \
# 0  title_761e82d05283bff6f1832c7164626e26
# 1  title_2a30a9b6a5a75250a7317c60c0f871e6
# 2  title_b89b152a0c80235c4e6174a96e98f166
# 3  title_9868eac5482fdbfebf7b94494bd078ec
# 4  title_08db9d62bccf3a51cb7ded0fdf666568
# 5  title_0ef200f6649ab2907625d4db1f796c87
# 6  title_0165dfcd088b4df972d8b23ee45198e0
# 7  title_55c16d853bfc26cc4697fe2158f2e273
# 8  title_ab7f6ea47a85aeacab878345864501df
# 9  title_3ed2e9ed1879767b09e706f2a7f5ced5
#
#                                                title  \
# 0  Woman Adopts Rescue Dog, Starts Noticing Foul ...
# 1  Grand Daughter Sings Favorite Song to Grandma ...
# 2  First Class Passenger Sees A Soldier Walking U...
# 3  Model Who Boasts She Transformed Into An Afric...
# 4  Dad Puts His Son Into The Game Days After Beat...
# 5  Little Girl’s Reaction To Shooting Her First D...
# 6  Out Of All The Holiday Recipes I’ve Tried, His...
# 7  A Starbucks Barista Couldn’t Find A Babysitter...
# 8  The Easily Offended Whine When Kelly Clarkson ...
# 9  During Heated Love Making, Wife Accidentally B...
#
#                                body_hash  \
# 0  body_072ebc1af96077202eb2ad843b6fe4cd
# 1  body_3e0c1daeb28fa250067a74240a5af93d
# 2  body_6953f3cbe02f2bdf2083937b1c8f9b7f
# 3  body_d9e3185ae65d5b97185f08d85c31abec
# 4  body_fcb8636125a87f14428856aff72e307f
# 5  body_c8d4436c055c1516d67af592b850a17f
# 6  body_7a5cb6d058bda9afc409df365438cc7f
# 7  body_b2277eca06c8bd84aba7a6512dcbb5e6
# 8  body_ddf7af702f3aef83dcb93cc5717ad34f
# 9  body_f62f488c90df847302cd010ff91e016b
#
#                                                 body       label  \
# 0  Kelly Benzel was looking for a new best friend...  unreliable
# 1  Dementia is one of the scariest and heartbreak...  unreliable
# 2  Air travel can be a tiring and trying experien...  unreliable
# 3  Martina Big, a 28-year-old white German model,...  unreliable
# 4  A cancer diagnosis never comes at the right ti...  unreliable
# 5  In the YouTube video below, you’re going to se...  unreliable
# 6  Once a year, the grocery stores start stocking...  unreliable
# 7  Starbucks can be a great place to get luxuriou...  unreliable
# 8  Dolling out corporal punishment is a controver...  unreliable
# 9  He always told her that he liked it rough. But...  unreliable
#
#                            url_hash
# 0  00d76dc2a2b9c02526ab6aba99cea68d
# 1  022b655e21ca0d38a1fc33f2a37165a8
# 2  0405cdbffb7b0f0aef94eafaba0863ff
# 3  09f269f0d217228587029f2012f875c9
# 4  0c739d0432f31e7805c0d62f6eff0849
# 5  154032234b0955080af9117e817a7676
# 6  1af9a9f5326071c7bc5a6e16e04a75df
# 7  201402629241e8945bc127ac0b387dc8
# 8  21825e99b66d5a6b55e9e3f8c5bdfe71
# 9  24c1a494a889e14ef274e14d31fca550

# %%
# BIgQuery count by domain
query_job = client.query(
    """
    SELECT
    DOMAIN_HASH
    , LABEL
    , COUNT(*) AS ARTICLES_COUNT
    FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
    GROUP BY DOMAIN_HASH, LABEL
    ORDER BY ARTICLES_COUNT DESC
    """
)

res_df = query_job.result().to_dataframe()  # Waits for job to complete.

# Tally the domain hash to ensure each domain only has one label
domain_tally_ls = []
duplicate_domain_tally_ls = []
for i, row in res_df.iterrows():
  if row['DOMAIN_HASH'] in domain_tally_ls:
    duplicate_domain_tally_ls += [True]
  else:
    duplicate_domain_tally_ls += [False]
  
  # Add domain hash to the list of domains already reviwed
  domain_tally_ls += [row['DOMAIN_HASH']]

res_df['DOMAIN_HAS_MULTIPLE_LABEL'] = duplicate_domain_tally_ls

res_df
# Out:
#                                  DOMAIN_HASH       LABEL  ARTICLES_COUNT  \
# 0    domain_8f00b2b61ba335244231d632d390bf8d        fake            7046
# 1    domain_9f5bbbcbad4a48edd86162fabbe90b6e   political            5441
# 2    domain_7e058b16a00bca2c3620d5147881e34d  conspiracy            2819
# 3    domain_98845529bda170844508657ae469197a        bias            1162
# 4    domain_2bb13bea21c458421e33179105662bdd   political            1061
# 5    domain_bd8db3098e8505e2d80c8b89a2eccdb8   clickbait             813
# 6    domain_0d6ca907eef322628f81ae5a38735d44        bias             730
# 7    domain_f573aed8d0dcf08ef6ce3efd5f5c48c0   political             729
# 8    domain_213f2e7f6968dd534eb43ef113fce3e1   political             671
# 9    domain_8fbb80fdc3a337fd46babecb01f203fa     junksci             615
# 10   domain_799497bdca60cb2f1522d66166f15274   political             435
# 11   domain_bfcde262dcc0a3fe874d75293764fb4c   political             415
# 12   domain_69a49c3be87af6ae0c48f5c9b005a21b        None             413
# 13   domain_f9f6f6f07772425d1522dd8a8ab25193        None             347
# 14   domain_5dfa617b9d6dac8de770c521298c4e53     junksci             294
# 15   domain_3cbda5292ac5c0b572a8d764b0e52eec        bias             209
# 16   domain_fb4e14ee232e6a6acfda1de4f10a1fe3   political             209
# 17   domain_c29df259d72ab43dc7e2c43b1941a1c9   clickbait             178
# 18   domain_6a12243e8071c910a53039000309c901    reliable             168
# 19   domain_7cc6378eb1ac3bf4455eb536225df80b        bias             160
# 20   domain_f9e7e3cf456dda4da1f7ada4ba6ddc8c  conspiracy             153
# 21   domain_191e287683c85a13fa54c85c43281769  conspiracy             152
# 22   domain_3e2b4bc8d67cf01a6f156413acc03375   clickbait             144
# 23   domain_1682643b797f67fe89d09642a50174fe   political             120
# 24   domain_b55734eb636ef77462a42b666bc74c5f     unknown             114
# 25   domain_714bf72800dbdc780c8b895adc12ae3c  unreliable             108
# 26   domain_bfff154f86499943be9f3e65798b5d53   political             107
# 27   domain_d061e62c09e8c363752ddfa81c54b3ba        bias              99
# 28   domain_a66294ec7d2d0d8e3b22c293a88d14f4   political              97
# 29   domain_8776e5a68ce1577dd2809b859c3c6d82   political              90
# 30   domain_5014c2313218bc048eaef8f34771d2eb     unknown              84
# 31   domain_f03bcedc7a83b5568ff986bfec2c3413  conspiracy              77
# 32   domain_9725d0802cf38288710d8bff8f64dcba  unreliable              76
# 33   domain_fa702aa239d1e1c37cc9c5d75ab9b4f9   political              75
# 34   domain_f22938424edda66ec091ddd069854179  unreliable              74
# 35   domain_77b6aa19bdd7ac5f26e593472bd9a7d5        hate              71
# 36   domain_6afcd6f29c592f5495589242b12d1c25   political              67
# 37   domain_2c6ca1a760cdc4987f4283c9464dc639        None              63
# 38   domain_090b7aeff850c5dda848d5b9e75bb16d     unknown              58
# 39   domain_f047cbddff341a471b7b05bd5f4ee660       rumor              57
# 40   domain_daf12fe2bd3c219af940a4f8891f23f0        bias              57
# 41   domain_bc6e2fd29bb66b366afa86a3934609ce  conspiracy              54
# 42   domain_dbbb88dd5835637c6c4b2e3c54c2669e   political              50
# 43   domain_b04f082dca5817be6d561c1e25ea2c16        None              48
# 44   domain_b2f824ff829b40551a0f7e99a53745a0      satire              47
# 45   domain_e23a8807f4586e5ab98d2c0d335d998a  conspiracy              45
# 46   domain_9c34eb473390528f31c0303bda283c21  unreliable              44
# 47   domain_95e62162e78b589ec6362d5a6a19b3cb        bias              43
# 48   domain_b0c5e6bffbaa50cb2a380e69d80f0fde        bias              42
# 49   domain_c072fb2a857d0288f93a765a423629c1  conspiracy              42
# 50   domain_9a0d9e918e815c1424ffff912643042f  unreliable              41
# 51   domain_f3408542d52cb5a4c7f9d764ba80713b        bias              41
# 52   domain_e1e8ae12f228f5344ff99f14eb6926e8        None              33
# 53   domain_dc7dbd0a07a4d8dcf91c1d6de72611ea  unreliable              33
# 54   domain_1d3355bc85a66dfd13a09f3412c7f085   clickbait              33
# 55   domain_f446297823e3381ccbdcadd1033349f8  conspiracy              32
# 56   domain_ae885395fb95bb58ee77f8ae3925d64c        None              32
# 57   domain_1c74052b1eb7f1b234c3c19714e65a53        bias              31
# 58   domain_f9a3693da598b15b2c9235cb8c2c3e74     junksci              30
# 59   domain_2e59c440f7b5b4a04a68f652f5b5333b   political              28
# 60   domain_670f9a1790abd5f611073d167d0b8181     unknown              27
# 61   domain_d9b91044b82468a930dbba5a1be97efe        None              27
# 62   domain_e405e81e7af8517d01f31f4148fc71f8        bias              26
# 63   domain_e34675b4f28a906f84eeae9b500db072        bias              26
# 64   domain_0691d86f4f2449106e6b812635ae6dc2  conspiracy              24
# 65   domain_e0ed6141030ad9697efb6c0fbeaaf39a        bias              23
# 66   domain_7e6e1c6f7cf959d4b9bb48a6343ae80a     unknown              23
# 67   domain_902091121d014e622d75cbc7366f2ee6  unreliable              22
# 68   domain_bf1876a5bd135bede0c8d6dceee56287        bias              21
# 69   domain_ef1bc2898cde8803366bc549a5db7810   political              21
# 70   domain_80983712743801d65edf8f982efb226f  conspiracy              20
# 71   domain_77bb545e808a339883519ec87b37568b  conspiracy              20
# 72   domain_6dd68b0f98a01bc7b818f07015b03045      satire              19
# 73   domain_2ec5c58f61208a4c8c63d34ab78b0d84     junksci              17
# 74   domain_ebe3d7d9918e288972a59e1ca7fad839   political              17
# 75   domain_8e9372b5e0f099519daea57d17d06dc8   political              17
# 76   domain_725ab69c90f5c175022e9fff121b86b3   political              17
# 77   domain_8bcdc1ff44fe95e8fa1dbc98837e2d61   clickbait              16
# 78   domain_6516070744623d5b202c1aed9c8cd167   clickbait              16
# 79   domain_b3561e4c69fc2c3c42caff5d09c06797   clickbait              16
# 80   domain_9ec5ddf6e6b6f4394e9aa78d1e0b7df5        bias              16
# 81   domain_f6467a39846eb29840eeacd10a72fa18        bias              15
# 82   domain_cd6751faf82670aa1def1f49d631f5b5   political              15
# 83   domain_26f4e8623af4740617dbcd58ea5ea79e   political              15
# 84   domain_625aa2cfe2431342ba06d4b1091e0068   political              15
# 85   domain_ef1f79a3352040ff1e53c4792e0f82da     unknown              15
# 86   domain_b5562cb6e482ead8e7b41ad374075d6c  conspiracy              15
# 87   domain_9a9c6420af59e59d64f6d6efec7010a4   political              14
# 88   domain_ff30c35599b4b1c1cf2452fd9bc516ec     unknown              14
# 89   domain_be43d3d4c70a94cb184229a094d40ce6     junksci              13
# 90   domain_98329bfee9ee10e6193bc6e2f9d68326        bias              13
# 91   domain_333fbef8f20680b2f64c9bcdbf507eed     junksci              13
# 92   domain_25516cc33d26c336d56269cc3e470ef4  conspiracy              12
# 93   domain_0962e477ba5ef22cfa8f9f2a2bf1cf84  unreliable              11
# 94   domain_e3782a046734ce84f943b186a6b3b0d5        bias              11
# 95   domain_6ae10a38ca73549a2e745ac334073bbc        bias              10
# 96   domain_fedb6741f5466a1f2b94f3067260b45a   political              10
# 97   domain_283e8bea1b4bda6cfaef09fd756f583e   clickbait              10
# 98   domain_8d01354aadbf9b5bcbf69cb21e763e20    reliable              10
# 99   domain_8d36e2d1e8fd855649ffe49a1f6a6a64      satire              10
# 100  domain_9eccd3e363d514276c6d0ebd272f44d0        fake               9
# 101  domain_92398575509fbcdaf15f3300afa90f82  unreliable               9
# 102  domain_d229b60c4e7d85bb990a7c0114c56a59        bias               9
# 103  domain_bbdcc034a7e7286fa666aca650af364d        fake               8
# 104  domain_c2234ca891fbd2e5dd8b12f0f7ee9e57      satire               8
# 105  domain_4e2accee075ea7805bff7247a3b08308      satire               8
# 106  domain_1b114e669a32fd5523ab9a0169c5526f  conspiracy               7
# 107  domain_71a2bece9250fc73754674151d08ff0d        None               7
# 108  domain_39897a1f691f4ab9d29e150bf51ca4e3   clickbait               7
# 109  domain_d9aafe4c74d4dc82bcc371c7b1b906aa  unreliable               7
# 110  domain_5e2d02afb13db09442866e35b80beede   political               7
# 111  domain_81df9d37c2cc747e36887f85f8f12291        bias               6
# 112  domain_4640929e97eeb7aa066e21c89e25820b  conspiracy               6
# 113  domain_2b1b045d2f61d3b09d3d9de9ca54d67a        bias               6
# 114  domain_be827dfcbca489825ce5ed5091b87927     junksci               6
# 115  domain_d0a759558f0e28181573400f92ac533b  conspiracy               6
# 116  domain_a214f72bae25b351d8634b42efe7c961   political               6
# 117  domain_0abb7ad0f22beeddeaa66923c9f569b9        None               6
# 118  domain_9b94de25cdebeb77fe13e9c1bd4b9fb5        bias               6
# 119  domain_8371c7af10f4ca25e0f4fc8dbfa34086        fake               6
# 120  domain_aa4214b2bb89178bf26ccb85c29e87f6  unreliable               6
# 121  domain_20f4995b3b26bfb3fd3452488b508456        bias               5
# 122  domain_32941baccecb0e4772a4a00a9ddc2032   political               5
# 123  domain_9e8e2939ae6fc4ddf7d3c76dd7cf36c7  conspiracy               5
# 124  domain_228a30c466f1d9b6f15b783ca6d4d373  conspiracy               4
# 125  domain_0414276445efcdda835ae60c21f1257e        bias               4
# 126  domain_4b2772cf50d1497e8e4542710501bd5f     unknown               4
# 127  domain_71cde77da2e380141d923d8e192664bd   political               4
# 128  domain_c97825129fe35bfe256d3d3bfd74a68e     unknown               4
# 129  domain_fa20655a74bbf3d55e6093dc3f7b0b4b  unreliable               4
# 130  domain_35826b2bd227588ccf7f5d2d95cb8ead        fake               4
# 131  domain_a915d10a9cfcb1aaa463065abb64d0d1   clickbait               4
# 132  domain_09820ddecb343a96e4652ee94f3428ca        bias               4
# 133  domain_d2ab080f3f6c3ab5324c3171d904fb60  conspiracy               4
# 134  domain_7c80f485502f774206c4a955c73ec895        hate               3
# 135  domain_6dad3160ea412c366c718565e5ed50c7     unknown               3
# 136  domain_7439469439bb49107e23976d674fe054        hate               3
# 137  domain_2cd6c7e5b52562e349b54f8be0ad1eeb        None               3
# 138  domain_e7e9fcbd693e97a538800e8f8925833d        hate               3
# 139  domain_19727e7dfa4b40d50e6106d3cdf857fe     unknown               3
# 140  domain_f78d3e640568317fdc197922a83cc72d        bias               3
# 141  domain_7fe8b5ec02f3695cac07561cb3f06677        fake               3
# 142  domain_ed8a6546f82a5cd9f8663ea4bde6e638        bias               3
# 143  domain_ae5b067247d663e6a82ad6155a8950dd  conspiracy               3
# 144  domain_1eed9d343826bffb2d74bbd4ab92d725        fake               3
# 145  domain_5cb44e1c01a3e6659607671d7617c71c     unknown               2
# 146  domain_c07e15a699d0b7a3a8a85ceb082d03fe   political               2
# 147  domain_9a199d5872634a001effaf9e77ce0bbd        None               2
# 148  domain_b5f37665109c5d1055995893ffdedf83  conspiracy               2
# 149  domain_36de50180e84c35fe490bb60ccfa067e        bias               2
# 150  domain_b3af9c51233e0ee4e3bcb4eb429b56f3   political               2
# 151  domain_a2c5ba2a6834dcb8746a36f47e5fb9b9  unreliable               2
# 152  domain_66db98138a7da5d72c8becf3de0e4a31  conspiracy               2
# 153  domain_2e1c4e22c4feed37c72507c50d0232b1        bias               2
# 154  domain_069c5397b1af30b2ab38464644711aee        bias               2
# 155  domain_78868c04b77593ab9ae127dda5efd135      satire               2
# 156  domain_3e839bfdee6b0a2eb70e21686a474dfe   political               2
# 157  domain_00ed2a703fcb79060875666b27504053   political               2
# 158  domain_a5857e1ce2f61a5b22f70494134eaac0   political               2
# 159  domain_daf3443ff02927463d91818cfe02b50d        None               2
# 160  domain_185873d1f902490c0e61f488ea3a1a38   political               2
# 161  domain_71330e38a062718d01bf5cc906f58672     junksci               2
# 162  domain_d4d6e1ae6cdb4845995e37a870d29e02      satire               2
# 163  domain_4edff1b5750068279fb2e0230c3e5380   political               1
# 164  domain_2be28cabf750b41cfa89597f6e109e09   political               1
# 165  domain_75682947d32750e21851aa6bd371c829  conspiracy               1
# 166  domain_bbb95b551f642db5d9c3989002c1fa33        None               1
# 167  domain_ff5fe3728818a1b918e6d1a0221716ab        hate               1
# 168  domain_e60f2f982aeb75e173c158dd80ba5af2   clickbait               1
# 169  domain_3954d5639a2834fc2c3824caec12ebcd  conspiracy               1
# 170  domain_2b07b24e5cb6e6ee114747a0176d17a0   political               1
# 171  domain_8b500e62a848954dd1df3752a8da5919   political               1
# 172  domain_be6ccf3f58b38f629fa375fc5df60420        bias               1
# 173  domain_edd5909690ceb130b58fbf2abf882375  conspiracy               1
# 174  domain_341c80afad6e3b47016255d47078e0a6  conspiracy               1
# 175  domain_06d7d51d4c0251a3b42ebbfe7a26f5b4        bias               1
# 176  domain_9115aacafa05635ab12db50b331b2e91        bias               1
# 177  domain_d978280431610509cd3c1ffc63b5fad8        None               1
# 178  domain_32fb6e587463e29e5c17ef19a723f4f5   political               1
# 179  domain_2898ce92e0f40e6ae0fcf2172a57d962        bias               1
# 180  domain_dba255fee48039bec885525f34d93e3e        bias               1
# 181  domain_6ac3c748825f6ec75a1d590a4a0705f8      satire               1
# 182  domain_6d6083851f81d52d437a7c1c0bfebb0f        None               1
# 183  domain_315c9d54a7b67cd86a25cab716293e8b        None               1
# 184  domain_55c086c1f40ba2288dcb5bed04be39c2  conspiracy               1
# 185  domain_6a0258f088f96492673c324f167e5c55     junksci               1
# 186  domain_d223fe1505a39aab5565c357e417496e  conspiracy               1
# 187  domain_62f88633026e6e8f7cb86822defbc42c        fake               1
# 188  domain_5915307cbdc2d2909020ed5faa694dd7     unknown               1
# 189  domain_f73519c65f641722420e8f4cb2f4558b      satire               1
# 190  domain_d9fd2e6eb72f086ac4c4dda5f07b1af6        None               1
# 191  domain_43e820fdaa1f382bb0f2ce99866f09dd        bias               1
# 192  domain_8f7fb8558dbdcec0671e88504feccff4        None               1
# 193  domain_d2c1ed6780580239ade03edf73667f3f     unknown               1
# 194  domain_c888f140f0c2cd64fd7ba563b93e8097  conspiracy               1
# 195  domain_53cf7b3ea378b82f5dd0f3d7804f2d2b      satire               1
# 196  domain_7278328ff5bc42b1a29d9b51e9d3b946        fake               1
# 197  domain_9eb562d7fa2e4a32de9de63ca385db72     junksci               1
# 198  domain_1a482c97f790497c9809e63070e977dc     unknown               1
# 199  domain_ca14a1a10b6d95a384476925f6fd8898     junksci               1
# 200  domain_a715dbd3cfdbec1f4775714657dd3eb4  conspiracy               1
# 201  domain_5e30b0d401dc7f00af5f509e4aee8f22        None               1
# 202  domain_02cb0e25d8e2a8950c674f2d77e05712   political               1
#
#      DOMAIN_HAS_MULTIPLE_LABEL
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# 5                        False
# 6                        False
# 7                        False
# 8                        False
# 9                        False
# 10                       False
# 11                       False
# 12                       False
# 13                       False
# 14                       False
# 15                       False
# 16                       False
# 17                       False
# 18                       False
# 19                       False
# 20                       False
# 21                       False
# 22                       False
# 23                       False
# 24                       False
# 25                       False
# 26                       False
# 27                       False
# 28                       False
# 29                       False
# 30                       False
# 31                       False
# 32                       False
# 33                       False
# 34                       False
# 35                       False
# 36                       False
# 37                       False
# 38                       False
# 39                       False
# 40                       False
# 41                       False
# 42                       False
# 43                       False
# 44                       False
# 45                       False
# 46                       False
# 47                       False
# 48                       False
# 49                       False
# 50                       False
# 51                       False
# 52                       False
# 53                       False
# 54                       False
# 55                       False
# 56                       False
# 57                       False
# 58                       False
# 59                       False
# 60                       False
# 61                       False
# 62                       False
# 63                       False
# 64                       False
# 65                       False
# 66                       False
# 67                       False
# 68                       False
# 69                       False
# 70                       False
# 71                       False
# 72                       False
# 73                       False
# 74                       False
# 75                       False
# 76                       False
# 77                       False
# 78                       False
# 79                       False
# 80                       False
# 81                       False
# 82                       False
# 83                       False
# 84                       False
# 85                       False
# 86                       False
# 87                       False
# 88                       False
# 89                       False
# 90                       False
# 91                       False
# 92                       False
# 93                       False
# 94                       False
# 95                       False
# 96                       False
# 97                       False
# 98                       False
# 99                       False
# 100                      False
# 101                      False
# 102                      False
# 103                      False
# 104                      False
# 105                      False
# 106                      False
# 107                      False
# 108                      False
# 109                      False
# 110                      False
# 111                      False
# 112                      False
# 113                      False
# 114                      False
# 115                      False
# 116                      False
# 117                      False
# 118                      False
# 119                      False
# 120                      False
# 121                      False
# 122                      False
# 123                      False
# 124                      False
# 125                      False
# 126                      False
# 127                      False
# 128                      False
# 129                      False
# 130                      False
# 131                      False
# 132                      False
# 133                      False
# 134                      False
# 135                      False
# 136                      False
# 137                      False
# 138                      False
# 139                      False
# 140                      False
# 141                      False
# 142                      False
# 143                      False
# 144                      False
# 145                      False
# 146                      False
# 147                      False
# 148                      False
# 149                      False
# 150                      False
# 151                      False
# 152                      False
# 153                      False
# 154                      False
# 155                      False
# 156                      False
# 157                      False
# 158                      False
# 159                      False
# 160                      False
# 161                      False
# 162                      False
# 163                      False
# 164                      False
# 165                      False
# 166                      False
# 167                      False
# 168                      False
# 169                      False
# 170                      False
# 171                      False
# 172                      False
# 173                      False
# 174                      False
# 175                      False
# 176                      False
# 177                      False
# 178                      False
# 179                      False
# 180                      False
# 181                      False
# 182                      False
# 183                      False
# 184                      False
# 185                      False
# 186                      False
# 187                      False
# 188                      False
# 189                      False
# 190                      False
# 191                      False
# 192                      False
# 193                      False
# 194                      False
# 195                      False
# 196                      False
# 197                      False
# 198                      False
# 199                      False
# 200                      False
# 201                      False
# 202                      False

# %%
# BIgQuery count by label
query_job = client.query(
    """
    SELECT
    LABEL
    , COUNT(*) AS LABEL_COUNT
    FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
    GROUP BY LABEL
    ORDER BY LABEL_COUNT DESC
    """
)

res_df = query_job.result().to_dataframe()

print('Total: {}'.format(res_df['LABEL_COUNT'].sum()))

res_df
# Out:
# Total: 27589
#          LABEL  LABEL_COUNT
# 0    political         9776
# 1         fake         7081
# 2   conspiracy         3512
# 3         bias         2793
# 4    clickbait         1238
# 5      junksci          993
# 6         None          990
# 7   unreliable          437
# 8      unknown          354
# 9     reliable          178
# 10      satire           99
# 11        hate           81
# 12       rumor           57

# %%
# BIgQuery list of URLs
query_job = client.query(
    """
    SELECT DISTINCT
    URL_HASH
    FROM `detect-fake-news-313201.fake_news_sql.src_fake_news`
    """
)

res_df = query_job.result().to_dataframe()

print('Total: {}'.format(res_df.shape[0]))

res_df.head()
# Out:
# Total: 27589
#                            URL_HASH
# 0  00d76dc2a2b9c02526ab6aba99cea68d
# 1  022b655e21ca0d38a1fc33f2a37165a8
# 2  0405cdbffb7b0f0aef94eafaba0863ff
# 3  09f269f0d217228587029f2012f875c9
# 4  0c739d0432f31e7805c0d62f6eff0849

# %% [markdown]
# Noted that there were no classification for 990 samples, and further 354 with unknown classifications.

# %% [markdown]
# ## Profile the data in GraphDB

# %%
# Install the wrapper package
# Source: https://github.com/RDFLib/sparqlwrapper
# !pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting rdflib>=4.0
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 8.0 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=4.0->sparqlwrapper) (2.4.7)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=4.0->sparqlwrapper) (57.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=4.0->sparqlwrapper) (1.15.0)
# Installing collected packages: isodate, rdflib, sparqlwrapper
# Successfully installed isodate-0.6.0 rdflib-6.0.2 sparqlwrapper-1.8.5

# %%
# Code based on: https://sparqlwrapper.readthedocs.io/en/latest/main.html
from SPARQLWrapper import SPARQLWrapper, JSON

queryString = """
PREFIX aa: <http://www.city.ac.uk/ds/inm363/aaron_altrock#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select (count(?url_hash) as ?url_count) where {
  # ?url_hash rdf:type aa:urlHash .
}
"""


sparql = SPARQLWrapper("http://35.246.120.165:7200/repositories/src_fake_news")
sparql.setReturnFormat(JSON)
sparql.setQuery(queryString)

try :
   res_dct = sparql.query().convert()
   print('OK')

except Exception as e:
   print('ERROR: {}'.format(e))
# Out:
# OK

# %%
# No. of URL hash in GraphDB
res_dct.get('results').get('bindings')[0].get('url_count').get('value')
# Out:
# '27589'

# %% [markdown]
# Therefore noted that the number of news articles as URL hashes were completely uploaded when compared to BigQury count given both have the same number of articles `27598`.

# %%
res_dct
# Out:
# {'head': {'vars': ['url_count']},
#  'results': {'bindings': [{'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '27589'}}]}}

# %% [markdown]
# ### No. of URL hashes

# %%
# Code based on: https://sparqlwrapper.readthedocs.io/en/latest/main.html

queryString = """
PREFIX aa: <http://www.city.ac.uk/ds/inm363/aaron_altrock#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select ?domain_hash ?label (count(?url_hash) as ?url_count) where {
  # ?domain_hash rdf:type aa:domainHash .
  # ?url_hash rdf:type aa:urlHash .
  # ?label rdf:type aa:newsLabel .
  # ?url_hash aa:has_domain_hash ?domain_hash .
  # ?url_hash aa:has_news_label ?label .
}
GROUP BY ?domain_hash ?label
ORDER BY ?url_count
"""


sparql = SPARQLWrapper("http://35.246.120.165:7200/repositories/src_fake_news")
sparql.setReturnFormat(JSON)
sparql.setQuery(queryString)

try :
   res_dct = sparql.query().convert()
   print('OK')

except Exception as e:
   print('ERROR: {}'.format(e))
# Out:
# OK

# %%
res_dct
# Out:
# {'head': {'vars': ['domain_hash', 'label', 'url_count']},
#  'results': {'bindings': [{'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_02cb0e25d8e2a8950c674f2d77e05712'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_06d7d51d4c0251a3b42ebbfe7a26f5b4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_1a482c97f790497c9809e63070e977dc'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2898ce92e0f40e6ae0fcf2172a57d962'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2b07b24e5cb6e6ee114747a0176d17a0'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2be28cabf750b41cfa89597f6e109e09'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_315c9d54a7b67cd86a25cab716293e8b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_32fb6e587463e29e5c17ef19a723f4f5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_341c80afad6e3b47016255d47078e0a6'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_3954d5639a2834fc2c3824caec12ebcd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_43e820fdaa1f382bb0f2ce99866f09dd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_4edff1b5750068279fb2e0230c3e5380'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_53cf7b3ea378b82f5dd0f3d7804f2d2b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_55c086c1f40ba2288dcb5bed04be39c2'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5915307cbdc2d2909020ed5faa694dd7'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5e30b0d401dc7f00af5f509e4aee8f22'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_62f88633026e6e8f7cb86822defbc42c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6a0258f088f96492673c324f167e5c55'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6ac3c748825f6ec75a1d590a4a0705f8'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6d6083851f81d52d437a7c1c0bfebb0f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7278328ff5bc42b1a29d9b51e9d3b946'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_75682947d32750e21851aa6bd371c829'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8b500e62a848954dd1df3752a8da5919'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8f7fb8558dbdcec0671e88504feccff4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9115aacafa05635ab12db50b331b2e91'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9eb562d7fa2e4a32de9de63ca385db72'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a715dbd3cfdbec1f4775714657dd3eb4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bbb95b551f642db5d9c3989002c1fa33'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_be6ccf3f58b38f629fa375fc5df60420'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_c888f140f0c2cd64fd7ba563b93e8097'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ca14a1a10b6d95a384476925f6fd8898'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d223fe1505a39aab5565c357e417496e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d2c1ed6780580239ade03edf73667f3f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d978280431610509cd3c1ffc63b5fad8'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d9fd2e6eb72f086ac4c4dda5f07b1af6'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_dba255fee48039bec885525f34d93e3e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_e60f2f982aeb75e173c158dd80ba5af2'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_edd5909690ceb130b58fbf2abf882375'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f73519c65f641722420e8f4cb2f4558b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ff5fe3728818a1b918e6d1a0221716ab'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#hate'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_00ed2a703fcb79060875666b27504053'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_069c5397b1af30b2ab38464644711aee'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_185873d1f902490c0e61f488ea3a1a38'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2e1c4e22c4feed37c72507c50d0232b1'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_36de50180e84c35fe490bb60ccfa067e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_3e839bfdee6b0a2eb70e21686a474dfe'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5cb44e1c01a3e6659607671d7617c71c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_66db98138a7da5d72c8becf3de0e4a31'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_71330e38a062718d01bf5cc906f58672'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_78868c04b77593ab9ae127dda5efd135'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9a199d5872634a001effaf9e77ce0bbd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a2c5ba2a6834dcb8746a36f47e5fb9b9'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a5857e1ce2f61a5b22f70494134eaac0'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b3af9c51233e0ee4e3bcb4eb429b56f3'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b5f37665109c5d1055995893ffdedf83'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_c07e15a699d0b7a3a8a85ceb082d03fe'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d4d6e1ae6cdb4845995e37a870d29e02'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_daf3443ff02927463d91818cfe02b50d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_19727e7dfa4b40d50e6106d3cdf857fe'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_1eed9d343826bffb2d74bbd4ab92d725'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2cd6c7e5b52562e349b54f8be0ad1eeb'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6dad3160ea412c366c718565e5ed50c7'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7439469439bb49107e23976d674fe054'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#hate'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7c80f485502f774206c4a955c73ec895'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#hate'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7fe8b5ec02f3695cac07561cb3f06677'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ae5b067247d663e6a82ad6155a8950dd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_e7e9fcbd693e97a538800e8f8925833d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#hate'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ed8a6546f82a5cd9f8663ea4bde6e638'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f78d3e640568317fdc197922a83cc72d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_0414276445efcdda835ae60c21f1257e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_09820ddecb343a96e4652ee94f3428ca'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_228a30c466f1d9b6f15b783ca6d4d373'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_35826b2bd227588ccf7f5d2d95cb8ead'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_4b2772cf50d1497e8e4542710501bd5f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_71cde77da2e380141d923d8e192664bd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a915d10a9cfcb1aaa463065abb64d0d1'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_c97825129fe35bfe256d3d3bfd74a68e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d2ab080f3f6c3ab5324c3171d904fb60'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_fa20655a74bbf3d55e6093dc3f7b0b4b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_20f4995b3b26bfb3fd3452488b508456'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_32941baccecb0e4772a4a00a9ddc2032'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9e8e2939ae6fc4ddf7d3c76dd7cf36c7'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_0abb7ad0f22beeddeaa66923c9f569b9'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2b1b045d2f61d3b09d3d9de9ca54d67a'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_4640929e97eeb7aa066e21c89e25820b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_81df9d37c2cc747e36887f85f8f12291'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8371c7af10f4ca25e0f4fc8dbfa34086'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9b94de25cdebeb77fe13e9c1bd4b9fb5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a214f72bae25b351d8634b42efe7c961'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_aa4214b2bb89178bf26ccb85c29e87f6'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_be827dfcbca489825ce5ed5091b87927'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d0a759558f0e28181573400f92ac533b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_1b114e669a32fd5523ab9a0169c5526f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_39897a1f691f4ab9d29e150bf51ca4e3'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5e2d02afb13db09442866e35b80beede'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_71a2bece9250fc73754674151d08ff0d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d9aafe4c74d4dc82bcc371c7b1b906aa'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_4e2accee075ea7805bff7247a3b08308'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '8'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bbdcc034a7e7286fa666aca650af364d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '8'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_c2234ca891fbd2e5dd8b12f0f7ee9e57'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '8'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_92398575509fbcdaf15f3300afa90f82'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '9'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9eccd3e363d514276c6d0ebd272f44d0'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '9'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d229b60c4e7d85bb990a7c0114c56a59'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '9'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_283e8bea1b4bda6cfaef09fd756f583e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6ae10a38ca73549a2e745ac334073bbc'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8d01354aadbf9b5bcbf69cb21e763e20'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#reliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8d36e2d1e8fd855649ffe49a1f6a6a64'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_fedb6741f5466a1f2b94f3067260b45a'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_0962e477ba5ef22cfa8f9f2a2bf1cf84'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '11'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_e3782a046734ce84f943b186a6b3b0d5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '11'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_25516cc33d26c336d56269cc3e470ef4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '12'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_333fbef8f20680b2f64c9bcdbf507eed'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '13'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_98329bfee9ee10e6193bc6e2f9d68326'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '13'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_be43d3d4c70a94cb184229a094d40ce6'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '13'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9a9c6420af59e59d64f6d6efec7010a4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '14'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ff30c35599b4b1c1cf2452fd9bc516ec'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '14'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_26f4e8623af4740617dbcd58ea5ea79e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_625aa2cfe2431342ba06d4b1091e0068'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b5562cb6e482ead8e7b41ad374075d6c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_cd6751faf82670aa1def1f49d631f5b5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ef1f79a3352040ff1e53c4792e0f82da'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f6467a39846eb29840eeacd10a72fa18'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6516070744623d5b202c1aed9c8cd167'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '16'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8bcdc1ff44fe95e8fa1dbc98837e2d61'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '16'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9ec5ddf6e6b6f4394e9aa78d1e0b7df5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '16'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b3561e4c69fc2c3c42caff5d09c06797'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '16'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2ec5c58f61208a4c8c63d34ab78b0d84'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '17'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_725ab69c90f5c175022e9fff121b86b3'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '17'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8e9372b5e0f099519daea57d17d06dc8'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '17'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_ebe3d7d9918e288972a59e1ca7fad839'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '17'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6dd68b0f98a01bc7b818f07015b03045'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#satire'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '19'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_77bb545e808a339883519ec87b37568b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '20'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_80983712743801d65edf8f982efb226f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '20'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bf1876a5bd135bede0c8d6dceee56287'},
#     'label': {'type': 'uri',
# ...
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '47'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b04f082dca5817be6d561c1e25ea2c16'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '48'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_dbbb88dd5835637c6c4b2e3c54c2669e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '50'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bc6e2fd29bb66b366afa86a3934609ce'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '54'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_daf12fe2bd3c219af940a4f8891f23f0'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '57'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f047cbddff341a471b7b05bd5f4ee660'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#rumor'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '57'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_090b7aeff850c5dda848d5b9e75bb16d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '58'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2c6ca1a760cdc4987f4283c9464dc639'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '63'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6afcd6f29c592f5495589242b12d1c25'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '67'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_77b6aa19bdd7ac5f26e593472bd9a7d5'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#hate'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '71'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f22938424edda66ec091ddd069854179'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '74'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_fa702aa239d1e1c37cc9c5d75ab9b4f9'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '75'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9725d0802cf38288710d8bff8f64dcba'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '76'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f03bcedc7a83b5568ff986bfec2c3413'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '77'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5014c2313218bc048eaef8f34771d2eb'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '84'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8776e5a68ce1577dd2809b859c3c6d82'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '90'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_a66294ec7d2d0d8e3b22c293a88d14f4'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '97'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_d061e62c09e8c363752ddfa81c54b3ba'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '99'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bfff154f86499943be9f3e65798b5d53'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '107'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_714bf72800dbdc780c8b895adc12ae3c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unreliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '108'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_b55734eb636ef77462a42b666bc74c5f'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#unknown'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '114'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_1682643b797f67fe89d09642a50174fe'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '120'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_3e2b4bc8d67cf01a6f156413acc03375'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '144'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_191e287683c85a13fa54c85c43281769'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '152'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f9e7e3cf456dda4da1f7ada4ba6ddc8c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '153'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7cc6378eb1ac3bf4455eb536225df80b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '160'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_6a12243e8071c910a53039000309c901'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#reliable'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '168'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_c29df259d72ab43dc7e2c43b1941a1c9'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '178'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_3cbda5292ac5c0b572a8d764b0e52eec'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '209'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_fb4e14ee232e6a6acfda1de4f10a1fe3'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '209'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_5dfa617b9d6dac8de770c521298c4e53'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '294'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f9f6f6f07772425d1522dd8a8ab25193'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '347'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_69a49c3be87af6ae0c48f5c9b005a21b'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '413'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bfcde262dcc0a3fe874d75293764fb4c'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '415'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_799497bdca60cb2f1522d66166f15274'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '435'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8fbb80fdc3a337fd46babecb01f203fa'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#junksci'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '615'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_213f2e7f6968dd534eb43ef113fce3e1'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '671'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_f573aed8d0dcf08ef6ce3efd5f5c48c0'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '729'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_0d6ca907eef322628f81ae5a38735d44'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '730'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_bd8db3098e8505e2d80c8b89a2eccdb8'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#clickbait'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '813'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_2bb13bea21c458421e33179105662bdd'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1061'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_98845529bda170844508657ae469197a'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#bias'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1162'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_7e058b16a00bca2c3620d5147881e34d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#conspiracy'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2819'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_9f5bbbcbad4a48edd86162fabbe90b6e'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#political'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5441'}},
#    {'domain_hash': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#domain_8f00b2b61ba335244231d632d390bf8d'},
#     'label': {'type': 'uri',
#      'value': 'http://www.city.ac.uk/ds/inm363/aaron_altrock#fake'},
#     'url_count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7046'}}]}}

# %%
import re
res_ls = res_dct.get('results').get('bindings')

# Helper func to transform SPARQLWrapper query result output (dict) to Pandas dataframe
def parse_to_dataframe(res_ls):

  # If query result has content then parse to data frame else return None
  if len(res_ls) > 0:
    # Get column names
    col_nm_ls = list(res_ls[0].keys())

    parsed_res_ls = []

    for res_dct in res_ls:
      __res_ls = []
      for k, v in res_dct.items():
        __res_ls += [v.get('value')]

      # __res_ls = [res_dct]
      parsed_res_ls += [__res_ls]
    
    res_df = pd.DataFrame.from_dict(parsed_res_ls)
    res_df.columns = col_nm_ls
    res_df.reset_index(inplace=True, drop=True)

    return res_df

  else:
    return None

# Parse dict output from SPARQL to Pandas data frame
domain_url_count_df = parse_to_dataframe(res_ls)

# Remove name space prefix
domain_url_count_df['domain_hash'] = domain_url_count_df['domain_hash'].map(lambda str: str[str.find('#') + 1:])
domain_url_count_df['label'] = domain_url_count_df['label'].map(lambda str: str[str.find('#') + 1:])

# Convert url_count to integer
domain_url_count_df['url_count'] = domain_url_count_df['url_count'].map(int)

# Count percentage
domain_url_count_df['url_count_pct'] = domain_url_count_df['url_count'].map(lambda val: val / domain_url_count_df['url_count'].sum() * 100)

domain_url_count_df.sort_values(by=['url_count'], ascending=False, inplace=True)

domain_url_count_df
# Out:
#                                  domain_hash       label  url_count  \
# 202  domain_8f00b2b61ba335244231d632d390bf8d        fake       7046
# 201  domain_9f5bbbcbad4a48edd86162fabbe90b6e   political       5441
# 200  domain_7e058b16a00bca2c3620d5147881e34d  conspiracy       2819
# 199  domain_98845529bda170844508657ae469197a        bias       1162
# 198  domain_2bb13bea21c458421e33179105662bdd   political       1061
# 197  domain_bd8db3098e8505e2d80c8b89a2eccdb8   clickbait        813
# 196  domain_0d6ca907eef322628f81ae5a38735d44        bias        730
# 195  domain_f573aed8d0dcf08ef6ce3efd5f5c48c0   political        729
# 194  domain_213f2e7f6968dd534eb43ef113fce3e1   political        671
# 193  domain_8fbb80fdc3a337fd46babecb01f203fa     junksci        615
# 192  domain_799497bdca60cb2f1522d66166f15274   political        435
# 191  domain_bfcde262dcc0a3fe874d75293764fb4c   political        415
# 190  domain_69a49c3be87af6ae0c48f5c9b005a21b                    413
# 189  domain_f9f6f6f07772425d1522dd8a8ab25193                    347
# 188  domain_5dfa617b9d6dac8de770c521298c4e53     junksci        294
# 187  domain_fb4e14ee232e6a6acfda1de4f10a1fe3   political        209
# 186  domain_3cbda5292ac5c0b572a8d764b0e52eec        bias        209
# 185  domain_c29df259d72ab43dc7e2c43b1941a1c9   clickbait        178
# 184  domain_6a12243e8071c910a53039000309c901    reliable        168
# 183  domain_7cc6378eb1ac3bf4455eb536225df80b        bias        160
# 182  domain_f9e7e3cf456dda4da1f7ada4ba6ddc8c  conspiracy        153
# 181  domain_191e287683c85a13fa54c85c43281769  conspiracy        152
# 180  domain_3e2b4bc8d67cf01a6f156413acc03375   clickbait        144
# 179  domain_1682643b797f67fe89d09642a50174fe   political        120
# 178  domain_b55734eb636ef77462a42b666bc74c5f     unknown        114
# 177  domain_714bf72800dbdc780c8b895adc12ae3c  unreliable        108
# 176  domain_bfff154f86499943be9f3e65798b5d53   political        107
# 175  domain_d061e62c09e8c363752ddfa81c54b3ba        bias         99
# 174  domain_a66294ec7d2d0d8e3b22c293a88d14f4   political         97
# 173  domain_8776e5a68ce1577dd2809b859c3c6d82   political         90
# 172  domain_5014c2313218bc048eaef8f34771d2eb     unknown         84
# 171  domain_f03bcedc7a83b5568ff986bfec2c3413  conspiracy         77
# 170  domain_9725d0802cf38288710d8bff8f64dcba  unreliable         76
# 169  domain_fa702aa239d1e1c37cc9c5d75ab9b4f9   political         75
# 168  domain_f22938424edda66ec091ddd069854179  unreliable         74
# 167  domain_77b6aa19bdd7ac5f26e593472bd9a7d5        hate         71
# 166  domain_6afcd6f29c592f5495589242b12d1c25   political         67
# 165  domain_2c6ca1a760cdc4987f4283c9464dc639                     63
# 164  domain_090b7aeff850c5dda848d5b9e75bb16d     unknown         58
# 163  domain_f047cbddff341a471b7b05bd5f4ee660       rumor         57
# 162  domain_daf12fe2bd3c219af940a4f8891f23f0        bias         57
# 161  domain_bc6e2fd29bb66b366afa86a3934609ce  conspiracy         54
# 160  domain_dbbb88dd5835637c6c4b2e3c54c2669e   political         50
# 159  domain_b04f082dca5817be6d561c1e25ea2c16                     48
# 158  domain_b2f824ff829b40551a0f7e99a53745a0      satire         47
# 157  domain_e23a8807f4586e5ab98d2c0d335d998a  conspiracy         45
# 156  domain_9c34eb473390528f31c0303bda283c21  unreliable         44
# 155  domain_95e62162e78b589ec6362d5a6a19b3cb        bias         43
# 154  domain_c072fb2a857d0288f93a765a423629c1  conspiracy         42
# 153  domain_b0c5e6bffbaa50cb2a380e69d80f0fde        bias         42
# 152  domain_f3408542d52cb5a4c7f9d764ba80713b        bias         41
# 151  domain_9a0d9e918e815c1424ffff912643042f  unreliable         41
# 150  domain_e1e8ae12f228f5344ff99f14eb6926e8                     33
# 149  domain_dc7dbd0a07a4d8dcf91c1d6de72611ea  unreliable         33
# 148  domain_1d3355bc85a66dfd13a09f3412c7f085   clickbait         33
# 147  domain_f446297823e3381ccbdcadd1033349f8  conspiracy         32
# 146  domain_ae885395fb95bb58ee77f8ae3925d64c                     32
# 145  domain_1c74052b1eb7f1b234c3c19714e65a53        bias         31
# 144  domain_f9a3693da598b15b2c9235cb8c2c3e74     junksci         30
# 143  domain_2e59c440f7b5b4a04a68f652f5b5333b   political         28
# 141  domain_670f9a1790abd5f611073d167d0b8181     unknown         27
# 142  domain_d9b91044b82468a930dbba5a1be97efe                     27
# 140  domain_e405e81e7af8517d01f31f4148fc71f8        bias         26
# 139  domain_e34675b4f28a906f84eeae9b500db072        bias         26
# 138  domain_0691d86f4f2449106e6b812635ae6dc2  conspiracy         24
# 137  domain_e0ed6141030ad9697efb6c0fbeaaf39a        bias         23
# 136  domain_7e6e1c6f7cf959d4b9bb48a6343ae80a     unknown         23
# 135  domain_902091121d014e622d75cbc7366f2ee6  unreliable         22
# 134  domain_ef1bc2898cde8803366bc549a5db7810   political         21
# 133  domain_bf1876a5bd135bede0c8d6dceee56287        bias         21
# 131  domain_77bb545e808a339883519ec87b37568b  conspiracy         20
# 132  domain_80983712743801d65edf8f982efb226f  conspiracy         20
# 130  domain_6dd68b0f98a01bc7b818f07015b03045      satire         19
# 126  domain_2ec5c58f61208a4c8c63d34ab78b0d84     junksci         17
# 127  domain_725ab69c90f5c175022e9fff121b86b3   political         17
# 128  domain_8e9372b5e0f099519daea57d17d06dc8   political         17
# 129  domain_ebe3d7d9918e288972a59e1ca7fad839   political         17
# 125  domain_b3561e4c69fc2c3c42caff5d09c06797   clickbait         16
# 124  domain_9ec5ddf6e6b6f4394e9aa78d1e0b7df5        bias         16
# 123  domain_8bcdc1ff44fe95e8fa1dbc98837e2d61   clickbait         16
# 122  domain_6516070744623d5b202c1aed9c8cd167   clickbait         16
# 119  domain_cd6751faf82670aa1def1f49d631f5b5   political         15
# 116  domain_26f4e8623af4740617dbcd58ea5ea79e   political         15
# 118  domain_b5562cb6e482ead8e7b41ad374075d6c  conspiracy         15
# 117  domain_625aa2cfe2431342ba06d4b1091e0068   political         15
# 120  domain_ef1f79a3352040ff1e53c4792e0f82da     unknown         15
# 121  domain_f6467a39846eb29840eeacd10a72fa18        bias         15
# 115  domain_ff30c35599b4b1c1cf2452fd9bc516ec     unknown         14
# 114  domain_9a9c6420af59e59d64f6d6efec7010a4   political         14
# 113  domain_be43d3d4c70a94cb184229a094d40ce6     junksci         13
# 112  domain_98329bfee9ee10e6193bc6e2f9d68326        bias         13
# 111  domain_333fbef8f20680b2f64c9bcdbf507eed     junksci         13
# 110  domain_25516cc33d26c336d56269cc3e470ef4  conspiracy         12
# 109  domain_e3782a046734ce84f943b186a6b3b0d5        bias         11
# 108  domain_0962e477ba5ef22cfa8f9f2a2bf1cf84  unreliable         11
# 105  domain_8d01354aadbf9b5bcbf69cb21e763e20    reliable         10
# 104  domain_6ae10a38ca73549a2e745ac334073bbc        bias         10
# 103  domain_283e8bea1b4bda6cfaef09fd756f583e   clickbait         10
# 106  domain_8d36e2d1e8fd855649ffe49a1f6a6a64      satire         10
# 107  domain_fedb6741f5466a1f2b94f3067260b45a   political         10
# 102  domain_d229b60c4e7d85bb990a7c0114c56a59        bias          9
# 101  domain_9eccd3e363d514276c6d0ebd272f44d0        fake          9
# 100  domain_92398575509fbcdaf15f3300afa90f82  unreliable          9
# 99   domain_c2234ca891fbd2e5dd8b12f0f7ee9e57      satire          8
# 98   domain_bbdcc034a7e7286fa666aca650af364d        fake          8
# 97   domain_4e2accee075ea7805bff7247a3b08308      satire          8
# 96   domain_d9aafe4c74d4dc82bcc371c7b1b906aa  unreliable          7
# 95   domain_71a2bece9250fc73754674151d08ff0d                      7
# 94   domain_5e2d02afb13db09442866e35b80beede   political          7
# 93   domain_39897a1f691f4ab9d29e150bf51ca4e3   clickbait          7
# 92   domain_1b114e669a32fd5523ab9a0169c5526f  conspiracy          7
# 87   domain_9b94de25cdebeb77fe13e9c1bd4b9fb5        bias          6
# 82   domain_0abb7ad0f22beeddeaa66923c9f569b9                      6
# 84   domain_4640929e97eeb7aa066e21c89e25820b  conspiracy          6
# 85   domain_81df9d37c2cc747e36887f85f8f12291        bias          6
# 86   domain_8371c7af10f4ca25e0f4fc8dbfa34086        fake          6
# 83   domain_2b1b045d2f61d3b09d3d9de9ca54d67a        bias          6
# 89   domain_aa4214b2bb89178bf26ccb85c29e87f6  unreliable          6
# 90   domain_be827dfcbca489825ce5ed5091b87927     junksci          6
# 91   domain_d0a759558f0e28181573400f92ac533b  conspiracy          6
# 88   domain_a214f72bae25b351d8634b42efe7c961   political          6
# 81   domain_9e8e2939ae6fc4ddf7d3c76dd7cf36c7  conspiracy          5
# 80   domain_32941baccecb0e4772a4a00a9ddc2032   political          5
# 79   domain_20f4995b3b26bfb3fd3452488b508456        bias          5
# 73   domain_4b2772cf50d1497e8e4542710501bd5f     unknown          4
# 69   domain_0414276445efcdda835ae60c21f1257e        bias          4
# 70   domain_09820ddecb343a96e4652ee94f3428ca        bias          4
# 71   domain_228a30c466f1d9b6f15b783ca6d4d373  conspiracy          4
# 72   domain_35826b2bd227588ccf7f5d2d95cb8ead        fake          4
# 75   domain_a915d10a9cfcb1aaa463065abb64d0d1   clickbait          4
# 74   domain_71cde77da2e380141d923d8e192664bd   political          4
# 76   domain_c97825129fe35bfe256d3d3bfd74a68e     unknown          4
# 77   domain_d2ab080f3f6c3ab5324c3171d904fb60  conspiracy          4
# 78   domain_fa20655a74bbf3d55e6093dc3f7b0b4b  unreliable          4
# 63   domain_7c80f485502f774206c4a955c73ec895        hate          3
# 58   domain_19727e7dfa4b40d50e6106d3cdf857fe     unknown          3
# 59   domain_1eed9d343826bffb2d74bbd4ab92d725        fake          3
# 60   domain_2cd6c7e5b52562e349b54f8be0ad1eeb                      3
# 62   domain_7439469439bb49107e23976d674fe054        hate          3
# 61   domain_6dad3160ea412c366c718565e5ed50c7     unknown          3
# 64   domain_7fe8b5ec02f3695cac07561cb3f06677        fake          3
# 65   domain_ae5b067247d663e6a82ad6155a8950dd  conspiracy          3
# 66   domain_e7e9fcbd693e97a538800e8f8925833d        hate          3
# 67   domain_ed8a6546f82a5cd9f8663ea4bde6e638        bias          3
# 68   domain_f78d3e640568317fdc197922a83cc72d        bias          3
# 40   domain_00ed2a703fcb79060875666b27504053   political          2
# 41   domain_069c5397b1af30b2ab38464644711aee        bias          2
# 42   domain_185873d1f902490c0e61f488ea3a1a38   political          2
# 43   domain_2e1c4e22c4feed37c72507c50d0232b1        bias          2
# 44   domain_36de50180e84c35fe490bb60ccfa067e        bias          2
# 45   domain_3e839bfdee6b0a2eb70e21686a474dfe   political          2
# 46   domain_5cb44e1c01a3e6659607671d7617c71c     unknown          2
# 48   domain_71330e38a062718d01bf5cc906f58672     junksci          2
# 47   domain_66db98138a7da5d72c8becf3de0e4a31  conspiracy          2
# 51   domain_a2c5ba2a6834dcb8746a36f47e5fb9b9  unreliable          2
# 49   domain_78868c04b77593ab9ae127dda5efd135      satire          2
# 52   domain_a5857e1ce2f61a5b22f70494134eaac0   political          2
# 53   domain_b3af9c51233e0ee4e3bcb4eb429b56f3   political          2
# 54   domain_b5f37665109c5d1055995893ffdedf83  conspiracy          2
# 55   domain_c07e15a699d0b7a3a8a85ceb082d03fe   political          2
# 56   domain_d4d6e1ae6cdb4845995e37a870d29e02      satire          2
# 57   domain_daf3443ff02927463d91818cfe02b50d                      2
# 50   domain_9a199d5872634a001effaf9e77ce0bbd                      2
# 14   domain_5915307cbdc2d2909020ed5faa694dd7     unknown          1
# 12   domain_53cf7b3ea378b82f5dd0f3d7804f2d2b      satire          1
# 13   domain_55c086c1f40ba2288dcb5bed04be39c2  conspiracy          1
# 18   domain_6ac3c748825f6ec75a1d590a4a0705f8      satire          1
# 15   domain_5e30b0d401dc7f00af5f509e4aee8f22                      1
# 16   domain_62f88633026e6e8f7cb86822defbc42c        fake          1
# 17   domain_6a0258f088f96492673c324f167e5c55     junksci          1
# 10   domain_43e820fdaa1f382bb0f2ce99866f09dd        bias          1
# 11   domain_4edff1b5750068279fb2e0230c3e5380   political          1
# 6    domain_315c9d54a7b67cd86a25cab716293e8b                      1
# 9    domain_3954d5639a2834fc2c3824caec12ebcd  conspiracy          1
# 8    domain_341c80afad6e3b47016255d47078e0a6  conspiracy          1
# 7    domain_32fb6e587463e29e5c17ef19a723f4f5   political          1
# 5    domain_2be28cabf750b41cfa89597f6e109e09   political          1
# 4    domain_2b07b24e5cb6e6ee114747a0176d17a0   political          1
# 3    domain_2898ce92e0f40e6ae0fcf2172a57d962        bias          1
# 2    domain_1a482c97f790497c9809e63070e977dc     unknown          1
# 20   domain_7278328ff5bc42b1a29d9b51e9d3b946        fake          1
# 19   domain_6d6083851f81d52d437a7c1c0bfebb0f                      1
# 1    domain_06d7d51d4c0251a3b42ebbfe7a26f5b4        bias          1
# 21   domain_75682947d32750e21851aa6bd371c829  conspiracy          1
# 22   domain_8b500e62a848954dd1df3752a8da5919   political          1
# 39   domain_ff5fe3728818a1b918e6d1a0221716ab        hate          1
# 38   domain_f73519c65f641722420e8f4cb2f4558b      satire          1
# 37   domain_edd5909690ceb130b58fbf2abf882375  conspiracy          1
# 36   domain_e60f2f982aeb75e173c158dd80ba5af2   clickbait          1
# 35   domain_dba255fee48039bec885525f34d93e3e        bias          1
# 34   domain_d9fd2e6eb72f086ac4c4dda5f07b1af6                      1
# 33   domain_d978280431610509cd3c1ffc63b5fad8                      1
# 32   domain_d2c1ed6780580239ade03edf73667f3f     unknown          1
# 31   domain_d223fe1505a39aab5565c357e417496e  conspiracy          1
# 30   domain_ca14a1a10b6d95a384476925f6fd8898     junksci          1
# 29   domain_c888f140f0c2cd64fd7ba563b93e8097  conspiracy          1
# 28   domain_be6ccf3f58b38f629fa375fc5df60420        bias          1
# 27   domain_bbb95b551f642db5d9c3989002c1fa33                      1
# 26   domain_a715dbd3cfdbec1f4775714657dd3eb4  conspiracy          1
# 25   domain_9eb562d7fa2e4a32de9de63ca385db72     junksci          1
# 24   domain_9115aacafa05635ab12db50b331b2e91        bias          1
# 23   domain_8f7fb8558dbdcec0671e88504feccff4                      1
# 0    domain_02cb0e25d8e2a8950c674f2d77e05712   political          1
#
#      url_count_pct
# 202      25.539164
# 201      19.721628
# 200      10.217840
# 199       4.211824
# 198       3.845736
# 197       2.946827
# 196       2.645982
# 195       2.642357
# 194       2.432129
# 193       2.229149
# 192       1.576715
# 191       1.504223
# 190       1.496973
# 189       1.257748
# 188       1.065642
# 187       0.757548
# 186       0.757548
# 185       0.645185
# 184       0.608938
# 183       0.579941
# 182       0.554569
# 181       0.550944
# 180       0.521947
# 179       0.434956
# 178       0.413208
# 177       0.391460
# 176       0.387836
# 175       0.358839
# 174       0.351589
# 173       0.326217
# 172       0.304469
# 171       0.279097
# 170       0.275472
# 169       0.271847
# 168       0.268223
# 167       0.257349
# 166       0.242850
# 165       0.228352
# 164       0.210229
# 163       0.206604
# 162       0.206604
# 161       0.195730
# 160       0.181232
# 159       0.173982
# 158       0.170358
# 157       0.163108
# 156       0.159484
# 155       0.155859
# 154       0.152235
# 153       0.152235
# 152       0.148610
# 151       0.148610
# 150       0.119613
# 149       0.119613
# 148       0.119613
# 147       0.115988
# 146       0.115988
# 145       0.112364
# 144       0.108739
# 143       0.101490
# 141       0.097865
# 142       0.097865
# 140       0.094240
# 139       0.094240
# 138       0.086991
# 137       0.083367
# 136       0.083367
# 135       0.079742
# 134       0.076117
# 133       0.076117
# 131       0.072493
# 132       0.072493
# 130       0.068868
# 126       0.061619
# 127       0.061619
# 128       0.061619
# 129       0.061619
# 125       0.057994
# 124       0.057994
# 123       0.057994
# 122       0.057994
# 119       0.054369
# 116       0.054369
# 118       0.054369
# 117       0.054369
# 120       0.054369
# 121       0.054369
# 115       0.050745
# 114       0.050745
# 113       0.047120
# 112       0.047120
# 111       0.047120
# 110       0.043496
# 109       0.039871
# 108       0.039871
# 105       0.036246
# 104       0.036246
# 103       0.036246
# 106       0.036246
# 107       0.036246
# 102       0.032622
# 101       0.032622
# 100       0.032622
# 99        0.028997
# 98        0.028997
# 97        0.028997
# 96        0.025372
# 95        0.025372
# 94        0.025372
# 93        0.025372
# 92        0.025372
# 87        0.021748
# 82        0.021748
# 84        0.021748
# 85        0.021748
# 86        0.021748
# 83        0.021748
# 89        0.021748
# 90        0.021748
# 91        0.021748
# 88        0.021748
# 81        0.018123
# 80        0.018123
# 79        0.018123
# 73        0.014499
# 69        0.014499
# 70        0.014499
# 71        0.014499
# 72        0.014499
# 75        0.014499
# 74        0.014499
# 76        0.014499
# 77        0.014499
# 78        0.014499
# 63        0.010874
# 58        0.010874
# 59        0.010874
# 60        0.010874
# 62        0.010874
# 61        0.010874
# 64        0.010874
# 65        0.010874
# 66        0.010874
# 67        0.010874
# 68        0.010874
# 40        0.007249
# 41        0.007249
# 42        0.007249
# 43        0.007249
# 44        0.007249
# 45        0.007249
# 46        0.007249
# 48        0.007249
# 47        0.007249
# 51        0.007249
# 49        0.007249
# 52        0.007249
# 53        0.007249
# 54        0.007249
# 55        0.007249
# 56        0.007249
# 57        0.007249
# 50        0.007249
# 14        0.003625
# 12        0.003625
# 13        0.003625
# 18        0.003625
# 15        0.003625
# 16        0.003625
# 17        0.003625
# 10        0.003625
# 11        0.003625
# 6         0.003625
# 9         0.003625
# 8         0.003625
# 7         0.003625
# 5         0.003625
# 4         0.003625
# 3         0.003625
# 2         0.003625
# 20        0.003625
# 19        0.003625
# 1         0.003625
# 21        0.003625
# 22        0.003625
# 39        0.003625
# 38        0.003625
# 37        0.003625
# 36        0.003625
# 35        0.003625
# 34        0.003625
# 33        0.003625
# 32        0.003625
# 31        0.003625
# 30        0.003625
# 29        0.003625
# 28        0.003625
# 27        0.003625
# 26        0.003625
# 25        0.003625
# 24        0.003625
# 23        0.003625
# 0         0.003625

# %%
# Summary of the classification by count of articles
label_count_df = domain_url_count_df[['label', 'url_count']].groupby('label').sum().sort_values(by='url_count', ascending=False).reset_index(drop=False)
total_rec_count = sum(label_count_df['url_count'].to_list())
print('Total number of articles: {}'.format(total_rec_count))
label_count_df['url_count_pct'] = label_count_df['url_count'].map(lambda val: val / total_rec_count * 100 if val is not None else 0)
label_count_df
# Out:
# Total number of articles: 27589
#          label  url_count  url_count_pct
# 0    political       9776      35.434412
# 1         fake       7081      25.666026
# 2   conspiracy       3512      12.729711
# 3         bias       2793      10.123600
# 4    clickbait       1238       4.487296
# 5      junksci        993       3.599261
# 6                     990       3.588387
# 7   unreliable        437       1.583965
# 8      unknown        354       1.283120
# 9     reliable        178       0.645185
# 10      satire         99       0.358839
# 11        hate         81       0.293595
# 12       rumor         57       0.206604

# %% [markdown]
# Per the https://github.com/several27/FakeNewsCorpus details on each news article classification noted no such classifications as `unknown` nor a classification of `None`.  These may be added by the author of the data set who performed scrapping to backfill classifications that could not be found.

# %%
# Save summary to CSV
label_count_df.to_csv(r'label_count_df.csv', index=False)

# %% [markdown]
# ## No. of domains by classification

# %%
print('No. of domains in total: {}'.format(domain_url_count_df['domain_hash'].shape[0]))
domain_count_df = domain_url_count_df[['domain_hash', 'label']].groupby(by='label').count().sort_values(by='domain_hash', ascending=False).reset_index()
domain_count_df.rename(columns={'domain_hash': 'domain_count'}, inplace=True)
domain_count_df['domain_count_pct'] = domain_count_df['domain_count'].map(lambda val: val / domain_count_df['domain_count'].sum() * 100)
domain_count_df.to_csv('domain_count_df.csv', index=False)
domain_count_df
# Out:
# No. of domains in total: 203
#          label  domain_count  domain_count_pct
# 0    political            40         19.704433
# 1         bias            37         18.226601
# 2   conspiracy            30         14.778325
# 3                         19          9.359606
# 4      unknown            15          7.389163
# 5   unreliable            13          6.403941
# 6    clickbait            11          5.418719
# 7      junksci            11          5.418719
# 8       satire            10          4.926108
# 9         fake             9          4.433498
# 10        hate             5          2.463054
# 11    reliable             2          0.985222
# 12       rumor             1          0.492611

# %% [markdown]
# ## Repeated publication of the same news articles

# %%
# Code based on: https://sparqlwrapper.readthedocs.io/en/latest/main.html

queryString = """
PREFIX aa: <http://www.city.ac.uk/ds/inm363/aaron_altrock#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select ?domain_hash ?url_hash ?body_hash ?label where {
  # ?domain_hash rdf:type aa:domainHash .
  # ?url_hash rdf:type aa:urlHash .
  # ?body_hash rdf:type aa:bodyHash .
  # ?label rdf:type aa:newsLabel .
  # ?url_hash aa:has_domain_hash ?domain_hash .
  # ?url_hash aa:has_news_label ?label .
  # ?url_hash aa:has_body_hash ?body_hash .
}
ORDER BY ?url_count
"""


sparql = SPARQLWrapper("http://35.246.120.165:7200/repositories/src_fake_news")
sparql.setReturnFormat(JSON)
sparql.setQuery(queryString)

try :
   res_dct = sparql.query().convert()
   print('OK')

except Exception as e:
   print('ERROR: {}'.format(e))


# Parse dict output from SPARQL to Pandas data frame
res_ls = res_dct.get('results').get('bindings')
domain_url_body_df = parse_to_dataframe(res_ls)

# Remove name space prefix
domain_url_body_df['domain_hash'] = domain_url_body_df['domain_hash'].map(lambda str: str[str.find('#') + 1:])
domain_url_body_df['url_hash'] = domain_url_body_df['url_hash'].map(lambda str: str[str.find('#') + 1:])
domain_url_body_df['body_hash'] = domain_url_body_df['body_hash'].map(lambda str: str[str.find('#') + 1:])
domain_url_body_df['label'] = domain_url_body_df['label'].map(lambda str: str[str.find('#') + 1:])

domain_url_body_df.head()
# Out:
# OK
#                                domain_hash                          url_hash  \
# 0  domain_8f00b2b61ba335244231d632d390bf8d  e681402ef05d57310574314a7918aa6c
# 1  domain_8f00b2b61ba335244231d632d390bf8d  3e3b0220abefd45f00916f2b69d13051
# 2  domain_8f00b2b61ba335244231d632d390bf8d  7c6de65487ed9706801ee482e5f4343f
# 3  domain_3e2b4bc8d67cf01a6f156413acc03375  4a883a995ada072079326ffb6d55f992
# 4  domain_9c34eb473390528f31c0303bda283c21  a4d57e74eaf6511fdcb675e1c7b55a15
#
#                                body_hash       label
# 0  body_0002ffe45350c699360f71e143099f38        fake
# 1  body_0004e310490d5711e38e13a0b0d6572b        fake
# 2  body_000767e358f2bd1225e8d3fe59a65276        fake
# 3  body_0008c819ef9503a60019f5b971b972e3   clickbait
# 4  body_0009bb573f65b94ab468528099f568cf  unreliable

# %%
domain_url_body_df[['body_hash', 'label', 'url_hash']].groupby(['body_hash', 'label']).count().reset_index().sort_values(by='url_hash', ascending=False).head(50)
# Out:
#                                    body_hash       label  url_hash
# 15548  body_a91766cb7db645f57aa52fca4b5a77e0        bias       410
# 12169  body_845af446af521c88c801695145743815     junksci       325
# 11210  body_7a03935701b11bf99ae50445a0e67793        fake        82
# 16030  body_ae1d6ee9a8d8345cd74e6983178a7a45   political        52
# 20048  body_d9ad78c5666f8bcb7c2b954427cdaa2b   political        43
# 3482   body_24dc2baef88f46a4c00982d270aa8388        bias        33
# 8956   body_61a2d8ac5c204e2b39450edef84b3bfa     unknown        24
# 7585   body_52ea6262c39b053fef53859b11c22898   political        22
# 17528  body_bdcab4fe046652ff22452f03c706d457   political        20
# 22566  body_f52d68dc3ff66be08eb737409be420de   political        19
# 3411   body_24169082b7c5b8414d6703a48787a6d2   political        18
# 8885   body_60c21389bb4a4cd12731fccc06c881ff   political        17
# 1557   body_104cd292cf557067a31df9f5880ee6ac     unknown        17
# 17176  body_ba27eef33707f849d061e2cac70561f3   political        16
# 26     body_004aead2316885ceb3110bbfe3e45d7b  unreliable        16
# 2595   body_1b56ecaf793aed4b11f34f1ddd92cc0b     unknown        16
# 17554  body_be1f954d72cdd9c6a192b7ab001dbb32   political        16
# 20041  body_d9a0f6a013d45e03154bdc5477c78e15  unreliable        15
# 6834   body_4a59e092325babed5f38efec4e9b5388   political        15
# 4358   body_2e469d7121985dc711f295fbddfabf4a   political        15
# 4807   body_33bb2eec086fb061e04a69bdcd121614  conspiracy        15
# 6864   body_4ab6810e0606f5bc7d00ceff05b2cacf        hate        14
# 8343   body_5ab5fe2d0dfdedee7695f6208e555082     unknown        14
# 14181  body_9a63206f652d5728c28360a0471c7cd0   political        14
# 20951  body_e3a926ca0ebd8cc4c0ce81008f09936f   political        14
# 23167  body_fb6c2393b0c4f26b353719352e72828e   political        14
# 21396  body_e88c948481ac3556a6431c7e59081100   political        13
# 11475  body_7ce39d8cefc1d200e08864fbca19aa36   political        13
# 3156   body_215b25e0e5a044b769c78d974f67dc94     unknown        13
# 19292  body_d0f327cde0b0e6a27db2f895ec488d94     junksci        13
# 2871   body_1e832dbbb9d997cc9a9ef411ea6c8ff3  conspiracy        13
# 21445  body_e8f57fb5a73400bbee877368f117071b   political        13
# 171    body_020aa4eef01c069ba7ec0a74b3098a63   political        13
# 17745  body_c0374a50776b3953cf81f9b12757b0e8   political        13
# 6946   body_4b9ab4126c644c773320b9dbb8a422a8   political        12
# 18100  body_c45902a6b1295aee7c48993a2effb354   political        12
# 3817   body_287c4f40da3cf64cb05802a795c22976                    12
# 13114  body_8e2afb05dc2f3be759ab5f337211d77c   political        11
# 6213   body_43690d958c059ed56b78a6a215e580bf   political        11
# 5966   body_4071f4cafd871e63f8fb74728ed43c29   political        11
# 4489   body_2f9c31ecd6719b8f0aad443835b4ce0d   political        11
# 13874  body_97212770a2e29fcbace8ca7fb287aae1   political        11
# 19992  body_d923f2ac09b2b6c5b916f517406154e3   political        10
# 6445   body_4607cfa57b2bb620e67015b42f6da131   political        10
# 4092   body_2b64bc6eff5282e34dad31fe2fa5c328   political        10
# 5253   body_388f84db423a9d353b2cdc0eda29f813   political        10
# 6002   body_40da8f78fad2370a711e297702fc2f38   political        10
# 21288  body_e75414dbe26c92309d6b61d5fc9eba2d   political        10
# 15637  body_aa1d47e2ba0ffa5e9b9833b10ecf61c7  conspiracy        10
# 11413  body_7c5bcd30da45a1cffb2b478b04e3f518   political         9
